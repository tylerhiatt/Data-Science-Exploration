# %% [markdown]
# <a href="https://colab.research.google.com/github/Michael-Holland-Dev/CS180/blob/main/data_science_labs/data_science_lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BYU CS 180 Lab 5: Cereal Data

# %% [markdown]
# ## Introduction:

# %% [markdown]
# Everyone loves cereal. But have you ever thought deeply about your cereal? Well now is your chance to take a data driven view of your breakfast.
# ![image-20210816-203922.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Getting Started:
# Download the data from github. Run the code below to download the data that you'll be using in this lab.
#
# You may use pandas, numpy, matplotlib and/or seaborn for these excercises.
#
# You can use/read their respective documentation in the links below (only if you need too, it's not required for the lab):
#
# *   Seaborn [Documentation]("https://seaborn.pydata.org/tutorial.html")
# *   Matplotlib [Documentation]("https://matplotlib.org/stable/api/index.html")
# *   Numpy [Documentation]("https://numpy.org/doc/1.23/user/index.html#user")
# *   Pandas [Documentation]("https://pandas.pydata.org/docs/user_guide/index.html#user-guide")

# %%
# !wget https://raw.githubusercontent.com/porterjenkins/cs180-intro-data-science/master/data/cereal.csv
# Out:
# --2022-10-06 20:55:49--  https://raw.githubusercontent.com/porterjenkins/cs180-intro-data-science/master/data/cereal.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4985 (4.9K) [text/plain]
# Saving to: 'cereal.csv.1'
#
# cereal.csv.1        100%[===================>]   4.87K  --.-KB/s    in 0s
#
# 2022-10-06 20:55:50 (21.1 MB/s) - 'cereal.csv.1' saved [4985/4985]

# %% [markdown]
# ## Exercise 1: Protein Powder
# Carbs, fats and proteins are the three primary macro nutrients. Create a figure plotting the distribution of each of these macro nutrients together (ie, three distributions on a single plot). Make sure to provide a legend.

# %%
# Enter all of your code for exercise 1 here. Feel free to add more cells if you need too:
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

cereal_df = pd.read_csv("./cereal.csv")
cereal_df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
sns.set(style="darkgrid")
fig = sns.kdeplot(cereal_df['carbo'], shade=True, color="r")
fig = sns.kdeplot(cereal_df['fat'], shade=True, color="b")
fig = sns.kdeplot(cereal_df['protein'], shade=True, color='g')
plt.legend( ["Carbs","Fats", "Proteins"], loc="upper right" )
plt.ylabel("Density")
plt.xlabel("Macronutrients")
plt.title("Primary Macronutrients Distribution")
plt.show()

# %% [markdown]
# ## Exercise 2: Sugar Daddy
# Get a list of the top 5 most sugary cereals and the 5 least sugary cereals.

# %%
# Enter all of your code for exercise 2 here. Feel free to add more cells if you need too:
cereal_df.sort_values(["sugars"], axis=0, ascending=[False], inplace=True)
cereal_df.head()
# Out:
#                      name mfr type  calories  protein  fat  sodium  fiber  \
# 66                 Smacks   K    C       110        2    1      70    1.0
# 30           Golden Crisp   P    C       100        2    0      45    0.0
# 70      Total Raisin Bran   G    C       140        3    1     190    4.0
# 52  Post Nat. Raisin Bran   P    C       120        3    1     200    6.0
# 6             Apple Jacks   K    C       110        2    0     125    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 66    9.0      15      40        25      2    1.00  0.75  31.230054
# 30   11.0      15      40        25      1    1.00  0.88  35.252444
# 70   15.0      14     230       100      3    1.50  1.00  28.592785
# 52   11.0      14     260        25      3    1.33  0.67  37.840594
# 6    11.0      14      30        25      2    1.00  1.00  33.174094

# %%
top_5 = cereal_df.head()
top_5_list = top_5['name'].tolist()
print(top_5_list)
# Out:
# ['Smacks', 'Golden Crisp', 'Total Raisin Bran', 'Post Nat. Raisin Bran', 'Apple Jacks']

# %%
cereal_df.tail()
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 55            Puffed Wheat   Q    C        50        2    0       0    1.0
# 54             Puffed Rice   Q    C        50        1    0       0    0.0
# 20  Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 63          Shredded Wheat   N    C        80        2    0       0    3.0
# 57          Quaker Oatmeal   Q    H       100        5    2       0    2.7
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 55   10.0       0      50         0      3    0.50  1.00  63.005645
# 54   13.0       0      15         0      3    0.50  1.00  60.756112
# 20   21.0       0      -1         0      2    1.00  1.00  64.533816
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 57   -1.0      -1     110         0      1    1.00  0.67  50.828392

# %%
bottom_5 = cereal_df.tail()
bottom_5_list = bottom_5['name'].tolist()
print(bottom_5_list)
# Out:
# ['Puffed Wheat', 'Puffed Rice', 'Cream of Wheat (Quick)', 'Shredded Wheat', 'Quaker Oatmeal']

# %% [markdown]
# ## Exercise 3: Cereal Killer
# Get a list of the top 5 highest rated and lowest rated cereals

# %%
# Enter all of your code for exercise 3 here. Feel free to add more cells if you need too:
cereal_df.sort_values(["rating"], axis=0, ascending=[False], inplace=True)
cereal_df.head()
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3     8.0       0     330        25      3    1.00  0.50  93.704912
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 63   16.0       0      95         0      1    0.83  1.00  68.235885

# %%
rating_top_5 = cereal_df.head()
rating_top_5_list = rating_top_5['name'].tolist()
print(rating_top_5_list)
# Out:
# ['All-Bran with Extra Fiber', "Shredded Wheat 'n'Bran", 'Shredded Wheat spoon size', '100% Bran', 'Shredded Wheat']

# %%
cereal_df.tail()
# Out:
#                      name mfr type  calories  protein  fat  sodium  fiber  \
# 14            Cocoa Puffs   G    C       110        1    1     180    0.0
# 18          Count Chocula   G    C       110        1    1     180    0.0
# 35       Honey Graham Ohs   Q    C       120        1    2     220    1.0
# 12  Cinnamon Toast Crunch   G    C       120        1    3     210    0.0
# 10           Cap'n'Crunch   Q    C       120        1    2     220    0.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 14   12.0      13      55        25      2     1.0  1.00  22.736446
# 18   12.0      13      65        25      2     1.0  1.00  22.396513
# 35   12.0      11      45        25      2     1.0  1.00  21.871292
# 12   13.0       9      45        25      2     1.0  0.75  19.823573
# 10   12.0      12      35        25      2     1.0  0.75  18.042851

# %%
rating_bottom_5 = cereal_df.tail()
rating_bottom_5_list = rating_bottom_5['name'].tolist()
print(rating_bottom_5_list)
# Out:
# ['Cocoa Puffs', 'Count Chocula', 'Honey Graham Ohs', 'Cinnamon Toast Crunch', "Cap'n'Crunch"]

# %% [markdown]
# ## Exercise 4: America
# Quantify the relationship between sugar and ratings.
#
# Make a plot to visualize this relationship. Superimpose a best fit line (with seaborn) to describe the relationship ([Seaborn RegPlot Documentation]("https://seaborn.pydata.org/generated/seaborn.regplot.html"))

# %%
# Make the plot for the data visualization and line of best fit here:

sns.scatterplot(data=cereal_df, x='sugars', y='rating')
sns.regplot(x=cereal_df['sugars'], y=cereal_df['rating'])
plt.title("Sugars vs Rating")
plt.xlabel("Sugars")
plt.ylabel("Rating")
plt.show()

# %% [markdown]
# Calculate a statistic describing the relationship between sugar and ratings  (i.e., correlation). Write a statement in plain English interpreting this statistic.

# %%
# Calculate the statistic using this cell:
x_value = cereal_df['sugars']
y_value = cereal_df['rating']
r = np.corrcoef(x_value, y_value)
r[0][1]
# Out:
# -0.7596746584301078

# %% [markdown]
# The Correlation Coefficient(r), whose limits span from -1 to 1, suggests the strength between two variavles. It is negative for the scatter plot between sugars (x-values) and rating (y-values), suggesting that there is a somewhat strong inverse relationship between the amount of sugars in a cereal and its rating. For example, generally speaking, the more sugars a cereal has, the lower its rating, as supported by the graph.

# %% [markdown]
# ## Exercise 5: America Part 2
# Make a few plots comparing the relationships of carbo, sugars, calories, protein, and fat with rating.

# %%
# Write your code to compare the various variables with rating below:
sns.scatterplot(data=cereal_df, x='carbo', y='rating')
sns.regplot(x=cereal_df['carbo'], y=cereal_df['rating'])
plt.title("Carbs vs Rating")
plt.xlabel("Carbs")
plt.ylabel("Rating")
plt.show()

# %%
x_value2 = cereal_df['carbo']
y_value2 = cereal_df['rating']
r = np.corrcoef(x_value2, y_value2)
r[0][1]
# Out:
# 0.05205466123376461

# %%
sns.scatterplot(data=cereal_df, x='calories', y='rating')
sns.regplot(x=cereal_df['calories'], y=cereal_df['rating'])
plt.title("Calories vs Rating")
plt.xlabel("Calories")
plt.ylabel("Rating")
plt.show()

# %%
x_value3 = cereal_df['calories']
y_value3 = cereal_df['rating']
r = np.corrcoef(x_value3, y_value3)
r[0][1]
# Out:
# -0.6893760311652588

# %%
sns.scatterplot(data=cereal_df, x='protein', y='rating')
sns.regplot(x=cereal_df['protein'], y=cereal_df['rating'])
plt.title("Protein vs Rating")
plt.xlabel("Protein")
plt.ylabel("Rating")
plt.show()

# %%
x_value4 = cereal_df['protein']
y_value4 = cereal_df['rating']
r = np.corrcoef(x_value4, y_value4)
r[0][1]
# Out:
# 0.4706184645492596

# %%
sns.scatterplot(data=cereal_df, x='fat', y='rating')
sns.regplot(x=cereal_df['fat'], y=cereal_df['rating'])
plt.title("Fat vs Rating")
plt.xlabel("Fat")
plt.ylabel("Ratings")
plt.show()

# %%
x_value5 = cereal_df['fat']
y_value5 = cereal_df['rating']
r = np.corrcoef(x_value5, y_value5)
r[0][1]
# Out:
# -0.4092836601478096

# %% [markdown]
# Of the variables carbo, sugars, calories, protein, and fat which has the strongest relationship with rating? Justify your answer.

# %% [markdown]
# Sugar vs. Rating: r = -0.760
# Carbs vs. Rating: r = 0.052
# Calories vs. Rating: r = -0.689
# Protein vs. Rating: r = 0.471
# Fat vs. Rating: r = -0.409
#
# Based on the value of the correlation coefficients for each of the scatterplots comparing a certain variable with rating, the variable with the strongest relationship with rating is sugars, whose correlation coefficient value is -0.760, suggesting a strong negative relationship between the amount of sugar contained in cereal and its corresponding rating.

# %% [markdown]
# ## Exercise 6: Preparing for Mt. Everest
# Do the same as you did with exercise 5, but instead compare carbo, sugars, protein, and fat with calories

# %%
# Write your code to compare the given variables with calories in this cell:
sns.scatterplot(data=cereal_df, x='carbo', y='calories')
sns.regplot(x=cereal_df['carbo'], y=cereal_df['calories'])
plt.title("Carbs vs Calories")
plt.xlabel("Carbs")
plt.ylabel("Calories")
plt.show()

# %%
r = np.corrcoef(cereal_df['carbo'], cereal_df['calories'])
r[0][1]
# Out:
# 0.2506809146989275

# %%
sns.scatterplot(data=cereal_df, x='sugars', y='calories')
sns.regplot(x=cereal_df['sugars'], y=cereal_df['calories'])
plt.title("Sugars vs Calories")
plt.xlabel("Sugars")
plt.ylabel("Calories")
plt.show()

# %%
r = np.corrcoef(cereal_df['sugars'], cereal_df['calories'])
r[0][1]
# Out:
# 0.5623402898034883

# %%
sns.scatterplot(data=cereal_df, x='protein', y='calories')
sns.regplot(x=cereal_df['protein'], y=cereal_df['calories'])
plt.title("Protein vs Calories")
plt.xlabel("Protein")
plt.ylabel("Calories")
plt.show()

# %%
r = np.corrcoef(cereal_df['protein'], cereal_df['calories'])
r[0][1]
# Out:
# 0.019066068232356962

# %%
sns.scatterplot(data=cereal_df, x='fat', y='calories')
sns.regplot(x=cereal_df['fat'], y=cereal_df['calories'])
plt.title("Fat vs Calories")
plt.xlabel("Fat")
plt.ylabel("Calories")
plt.show()

# %%
r = np.corrcoef(cereal_df['fat'], cereal_df['calories'])
r[0][1]
# Out:
# 0.49860981430038764

# %% [markdown]
# Of the variables carbo, sugars, protein, and fat which has the strongest relationship with calories? Justify your answer.

# %% [markdown]
# Carbs vs. Calories: r = 0.251
# Sugars vs. Calories: r = 0.562
# Protein vs. Calories: r = 0.019
# Fat vs. Calories: r = 0.499
#
# Based on the value of the correlation coefficients for each of the scatterplots comparing a certain variable with calories, the variable with the strongest relationship with calories is sugars, whose correlation coefficient value is 0.562, suggesting a strong positive relationship between the amount of sugar contained in cereal and the corresponding amount of calories.

# %% [markdown]
# ## Exercise 7: It’s Hot and It's Cold
# The type column has two values: H='hot' and C='cold'. What is the average rating by type?

# %%
# Write your code to get the average rating by type of cereal below:
pd.pivot_table( cereal_df, index=["type"], values=["rating"], aggfunc=[np.mean])
# Out:
#            mean
#          rating
# type
# C     42.095218
# H     56.737708

# %% [markdown]
# ## Exercise 8: Captain Crunch the Numbers
# Provide one additional insight from this dataset that you found interesting. Create at least one figure and explain why the insight was interesting to you.

# %%
# Create the extra plot below:
summary = cereal_df.describe()
summary
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
sns.boxplot(data=summary)
plt.xticks(rotation=90)
plt.show()

# %%
sns.kdeplot(data=cereal_df, x="sodium")
# Out:
# <AxesSubplot:xlabel='sodium', ylabel='Density'>

# %%
sns.kdeplot(data=cereal_df, x="potass")
# Out:
# <AxesSubplot:xlabel='potass', ylabel='Density'>

# %%
sns.scatterplot(data=cereal_df, x='sodium', y='rating')
sns.regplot(x=cereal_df['sodium'], y=cereal_df['rating'])
plt.title("Sodium vs Rating")
plt.xlabel("Sodium")
plt.ylabel("Rating")
plt.show()

# %%
sns.scatterplot(data=cereal_df, x='potass', y='rating')
sns.regplot(x=cereal_df['potass'], y=cereal_df['rating'])
plt.title("Potassium vs Rating")
plt.xlabel("Potassium")
plt.ylabel("Rating")
plt.show()

# %% [markdown]
# An interesting insight from the summary of the dataset is the high variance of the two variables sodium and potassium. Although both distributions have similar range in the amount of sodium and potassium respectively, one could potentially draw different conclusions. It can be observed from the density plot alone that with both variables, different kinds of cereals vary greatly with respect to serving size without seeming to make a big difference on its rating. However, with a closer look at the boxplot, it can be deceiving until the potassium outlier is recognized, which seems to greatly skew the distribution, when in reality these two variables are telling different stories.
